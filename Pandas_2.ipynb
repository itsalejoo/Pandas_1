# %% [markdown]
# <a href="https://colab.research.google.com/github/itsalejoo/Pandas_1/blob/main/Pandas_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install pandas
import pandas as pd

# %%
encuesta=pd.DataFrame({
    "julia":["me gusto", "fue horrible"],
    "pedro":["fue delicioso", "No estuvo mal"],
},
    index =["restaurante_1", "restaurante_2"],
)
encuesta
# Out:
#                       julia          pedro
# restaurante_1      me gusto  fue delicioso
# restaurante_2  fue horrible  No estuvo mal

# %%
miTitanic=pd.read_csv("titanic.csv")
miTitanic.shape
miTitanic.head()
# Out:
#    PassengerId  Survived
# 0          892         0
# 1          893         0
# 2          894         0
# 3          895         0
# 4          896         1

# %%
miTitanicFiltrado= miTitanic[miTitanic["Survived"]==0]
miTitanicFiltrado.count()
# Out:
# PassengerId    265
# Survived       265
# dtype: int64

# %%
miTitanicFiltrado = miTitanic[miTitanic["Survived"] == 1]
miTitanicFiltrado.sum()
# Out:
# PassengerId    167158
# Survived          153
# dtype: int64

# %%
# Leer el archivo CSV
miTarea= pd.read_csv("wages_cleaned.csv")
miTarea.shape
miTarea.head()
# Out:
#    Is_top_5_League  Based_rich_nation  Is_top_ranked_nation  EU_National  \
# 0                0                  1                     2            1
# 1                0                  1                     2            1
# 2                0                  1                     2            1
# 3                0                  1                     2            0
# 4                1                  1                     2            1
#
#     Caps  Apps   Age  Reputation  Is_top_prev_club  Last_Transfer_Fee  \
# 0  200.0   673  38.0      7629.0                 0                  0
# 1   97.0   555  35.0      8250.0                 0                  0
# 2  124.0   340  31.0      9000.0                 1                  0
# 3    0.0   245  25.0      7414.0                 0                  0
# 4   70.0   221  24.0      9415.0                 0                  0
#
#         Salary
# 0  203478000.0
# 1  199452000.0
# 2  149589000.0
# 3   74157000.0
# 4   48467000.0
